# %% [markdown]
# https://boto3.amazonaws.com/v1/documentation/api/latest/guide/quickstart.html#configuration
#
# https://docs.aws.amazon.com/code-samples/latest/catalog/code-catalog-python-example_code-textract.html
#
# https://docs.aws.amazon.com/textract/latest/dg/what-is.html

# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-0.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext dotenv
# %dotenv /home/jovyan/work/.env

# %%
# Copyright Amazon.com, Inc. or its affiliates. All Rights Reserved.
# SPDX-License-Identifier: Apache-2.0

"""
Purpose

Shows how to use the AWS SDK for Python (Boto3) with Amazon Textract to
detect text, form, and table elements in document images.
"""

import json
import logging
import boto3
from botocore.exceptions import ClientError

logger = logging.getLogger(__name__)

# snippet-start:[python.example_code.textract.TextractWrapper]
class TextractWrapper:
    """Encapsulates Textract functions."""
    def __init__(self, textract_client, s3_resource, sqs_resource):
        """
        :param textract_client: A Boto3 Textract client.
        :param s3_resource: A Boto3 Amazon S3 resource.
        :param sqs_resource: A Boto3 Amazon SQS resource.
        """
        self.textract_client = textract_client
        self.s3_resource = s3_resource
        self.sqs_resource = sqs_resource
    # snippet-end:[python.example_code.textract.TextractWrapper]
    
    # snippet-start:[python.example_code.textract.StartDocumentAnalysis]
    def start_analysis_job(
            self, bucket_name, document_file_name, feature_types, sns_topic_arn,
            sns_role_arn):
        """
        Starts an asynchronous job to detect text and additional elements, such as
        forms or tables, in an image stored in an Amazon S3 bucket. Textract publishes
        a notification to the specified Amazon SNS topic when the job completes.
        The image must be in PNG, JPG, or PDF format.
        :param bucket_name: The name of the Amazon S3 bucket that contains the image.
        :param document_file_name: The name of the document image stored in Amazon S3.
        :param feature_types: The types of additional document features to detect.
        :param sns_topic_arn: The Amazon Resource Name (ARN) of an Amazon SNS topic
                              where job completion notification is published.
        :param sns_role_arn: The ARN of an AWS Identity and Access Management (IAM)
                             role that can be assumed by Textract and grants permission
                             to publish to the Amazon SNS topic.
        :return: The ID of the job.
        """
        try:
            response = self.textract_client.start_document_analysis(
                DocumentLocation={
                    'S3Object': {'Bucket': bucket_name, 'Name': document_file_name}},
                NotificationChannel={
                    'SNSTopicArn': sns_topic_arn, 'RoleArn': sns_role_arn},
                FeatureTypes=feature_types)
            job_id = response['JobId']
            logger.info(
                "Started text analysis job %s on %s.", job_id, document_file_name)
        except ClientError:
            logger.exception("Couldn't analyze text in %s.", document_file_name)
            raise
        else:
            return job_id
    # snippet-end:[python.example_code.textract.StartDocumentAnalysis]

# %% [markdown]
# ### How to Use Amazon Textract
#
# * [How to Use Amazon Textract](https://stackoverflow.com/questions/59038306/how-to-use-the-amazon-textract-with-pdf-files)
#
# * Create new S3 bucket in console and write down bucket name, then:
# * Run the code.
# * It may take 5-50 seconds, until the call to ```get_document_text_detection(...)``` returns a result. Before, it will say that it is still processing.
# * According to my understanding, for each token, exactly one paid API call will be performed - and a past one will be retrieved, if the token has appeared in the past.
# * For Large documents: There is one intricacy if the document is large, in which case the result may need to be stitched together from multiple 'pages'. The kind of code you will need to add is:
#
# ```
# pages = [response]
# while nextToken := response.get('NextToken'):
#     response = client.get_document_text_detection(JobId=jobid, NextToken=nextToken)
#     pages.append(response)
# ```
#
# #### Retrieving the Response
#
# * JobId
# * The identifier for the document text detection job. Use JobId to identify the job in a subsequent call to GetDocumentAnalysis. A JobId value is only valid for 7 days.

# %%
if __name__ == "__main__":
    
    from dotenv import load_dotenv
    import random
    from time import sleep
    import os
    load_dotenv()
    import json
    import logging
    logging.basicConfig(level=logging.INFO,force = True)
    import boto3
    from botocore.exceptions import ClientError

    bucketName = 'textract-input-20221001'
    documentFileName='example.pdf'
    ACCESS_KEY = os.getenv("ACCESS_KEY")
    SECRET_KEY = os.getenv("SECRET_KEY")

    textractClient = boto3.client('textract', 
                          region_name='us-east-1', 
                          aws_access_key_id=ACCESS_KEY,
                          aws_secret_access_key=SECRET_KEY)
    
    s3Resource = boto3.resource('s3',  
                      aws_access_key_id=ACCESS_KEY,
                      aws_secret_access_key=SECRET_KEY)
    
    # possible_feature_types = ['TABLES','FORMS','QUERIES']
    feature_types = ['TABLES']

    s3bucket = s3Resource.Bucket(bucketName)

    extracted_data = []
    for s3_file in s3bucket.objects.all():
        print(s3_file)
        
        # use textract to process s3 file
        response = textractClient.start_document_analysis(
                DocumentLocation={'S3Object': {'Bucket': bucket, 'Name': s3_file.key}},
                # ClientRequestToken=random.randint(1,1e10),
                FeatureTypes=feature_types)

        job_Id = response['JobId']
        logger.info("Started text analysis job on job_id: ", job_id, "s3_file.key: ", s3_file.key)

        # sleep 2 seconds to prevent ProvisionedThroughputExceededException
        sleep(2)        
        
        """
        blocks=response['Blocks']

        for block in blocks:
                if block['BlockType'] != 'PAGE':
                    print('Detected: ' + block['Text'])
                    print('Confidence: ' + "{:.2f}".format(block['Confidence']) + "%")
                    
                    # Example case where you want to extract words with #
                    if("#" in block['Text']):
                        words = block['Text'].split()
                        for word in words:
                               if("#" in word):
                                    extracted_data.append({"word" : word, "file" : s3_file.key, "confidence": "{:.2f}".format(block['Confidence']) + "%"})

        df = pd.DataFrame(extracted_data)
        df = df.drop_duplicates()
        df.to_csv('output.csv')
    
        """
# Out:
# s3.ObjectSummary(bucket_name='textract-input-20221001', key='example.pdf')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/opt/conda/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/conda/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/opt/conda/lib/python3.10/site-packages/traitlets/config/application.py", line 976, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/opt/conda/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/opt/conda/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_107/1633583179.py", line 44, in <cell line: 1>
#     logger.info("Started text analysis job on: ", job_id, s3_file.key)
# Message: 'Started text analysis job on: '
# Arguments: ('da5cb1e7daeb0f8f882782292a5304951bb394a6e9286d836bf887b64d00c9f7', 'example.pdf')

# %%
extractedData = textractClient.get_document_analysis(JobId=job_Id)

# %%
print("Hi")
# Out:
# Hi

# %% [markdown]
# ### How to Use Output of AWS Textract Form
#
# * After having extracted a form from an example PDF and recieved a jobID, a large json object will result.
# * There is basically pre-written AWS code which shows how to convert said information into a CSV which can be adapted.
#
# * [Pre-written CSV Table Example](https://docs.aws.amazon.com/textract/latest/dg/examples-export-table-csv.html)
#
# * Note that there are both synchronous and asynchronous versions.

# %%
import boto3
from pprint import pprint

jobId = 'da5cb1e7daeb0f8f882782292a5304951bb394a6e9286d836bf887b64d00c9f7'
region_name = 'us-east-1'
file_name = 'output'

textract = boto3.client('textract', region_name=region_name)

# Display information about a block
def DisplayBlockInfo(block):
    print("Block Id: " + block['Id'])
    print("Type: " + block['BlockType'])
    if 'EntityTypes' in block:
        print('EntityTypes: {}'.format(block['EntityTypes']))

    if 'Text' in block:
        print("Text: " + block['Text'])

    if block['BlockType'] != 'PAGE':
        print("Confidence: " + "{:.2f}".format(block['Confidence']) + "%")

def GetResults(jobId, file_name):
    maxResults = 1000
    paginationToken = None
    finished = False

    while finished == False:

        response = None

        if paginationToken == None:
            response = textract.get_document_analysis(JobId=jobId, MaxResults=maxResults)
        else:
            response = textract.get_document_analysis(JobId=jobId, MaxResults=maxResults,
                                                           NextToken=paginationToken)

        blocks = response['Blocks']
        table_csv = get_table_csv_results(blocks)
        output_file = file_name + ".csv"
        # replace content
        with open(output_file, "at") as fout:
            fout.write(table_csv)
        # show the results
        print('Detected Document Text')
        print('Pages: {}'.format(response['DocumentMetadata']['Pages']))
        print('OUTPUT TO CSV FILE: ', output_file)

        # Display block information
        for block in blocks:
            DisplayBlockInfo(block)
            print()
            print()

        if 'NextToken' in response:
            paginationToken = response['NextToken']
        else:
            finished = True


def get_rows_columns_map(table_result, blocks_map):
    rows = {}
    for relationship in table_result['Relationships']:
        if relationship['Type'] == 'CHILD':
            for child_id in relationship['Ids']:
                try:
                    cell = blocks_map[child_id]
                    if cell['BlockType'] == 'CELL':
                        row_index = cell['RowIndex']
                        col_index = cell['ColumnIndex']
                        if row_index not in rows:
                            # create new row
                            rows[row_index] = {}

                        # get the text value
                        rows[row_index][col_index] = get_text(cell, blocks_map)
                except KeyError:
                    print("Error extracting Table data - {}:".format(KeyError))
                    pass
    return rows


def get_text(result, blocks_map):
    text = ''
    if 'Relationships' in result:
        for relationship in result['Relationships']:
            if relationship['Type'] == 'CHILD':
                for child_id in relationship['Ids']:
                    try:
                        word = blocks_map[child_id]
                        if word['BlockType'] == 'WORD':
                            text += word['Text'] + ' '
                        if word['BlockType'] == 'SELECTION_ELEMENT':
                            if word['SelectionStatus'] == 'SELECTED':
                                text += 'X '
                    except KeyError:
                        print("Error extracting Table data - {}:".format(KeyError))

    return text


def get_table_csv_results(blocks):

    pprint(blocks)

    blocks_map = {}
    table_blocks = []
    for block in blocks:
        blocks_map[block['Id']] = block
        if block['BlockType'] == "TABLE":
            table_blocks.append(block)

    if len(table_blocks) <= 0:
        return "<b> NO Table FOUND </b>"

    csv = ''
    for index, table in enumerate(table_blocks):
        csv += generate_table_csv(table, blocks_map, index + 1)
        csv += '\n\n'
        # In order to generate separate CSV file for every table, uncomment code below
        #inner_csv = ''
        #inner_csv += generate_table_csv(table, blocks_map, index + 1)
        #inner_csv += '\n\n'
        #output_file = file_name + "___" + str(index) + ".csv"
        # replace content
        #with open(output_file, "at") as fout:
        #    fout.write(inner_csv)

    return csv


def generate_table_csv(table_result, blocks_map, table_index):
    rows = get_rows_columns_map(table_result, blocks_map)

    table_id = 'Table_' + str(table_index)

    # get cells.
    csv = 'Table: {0}\n\n'.format(table_id)

    for row_index, cols in rows.items():

        for col_index, text in cols.items():
            csv += '{}'.format(text) + ","
        csv += '\n'

    csv += '\n\n\n'
    return csv

response_blocks = GetResults(jobId, file_name)

generate_table_csv(table_result, blocks_map, table_index)
# Out:
# [{'BlockType': 'PAGE',
#   'Geometry': {'BoundingBox': {'Height': 1.0,
#                                'Left': 0.0,
#                                'Top': 0.0,
#                                'Width': 1.0},
#                'Polygon': [{'X': 1.5849614334573464e-16, 'Y': 0.0},
#                            {'X': 1.0, 'Y': 9.462437987838284e-17},
#                            {'X': 1.0, 'Y': 1.0},
#                            {'X': 0.0, 'Y': 1.0}]},
#   'Id': 'a0a56d07-8647-47f9-a521-41fdce32e714',
#   'Page': 1,
#   'Relationships': [{'Ids': ['65983361-5294-49ca-b239-ee79ceffc973',
#                              '00053d7e-aca9-4a9f-ab5e-348c756a4bd4',
#                              '0322fb52-d7a4-407f-aa42-9ddc181f06c3',
#                              '9eb96d51-4cc8-44ef-9a12-c57d0612fa08',
#                              '89f40669-66d7-414c-ad3b-8a1affb08765',
#                              '854d0434-62b1-4728-92ee-7aeca32b84bb',
#                              '17206335-c210-4cc2-8284-026e7fa483ca',
#                              '32896660-276c-4d79-9e8b-a5492bb5778e',
#                              '0cb6b938-9a8d-4064-9690-d6a34be4339d',
#                              '168a91f7-3e07-4f26-8728-c4ec6bba45ee',
#                              'cbe27eff-cf96-422b-9196-b8d4d61b0e36',
#                              '2729e90e-45ca-410f-8bb7-7e6adfce2fb0',
#                              'aab76d80-8661-482e-af4b-cda4c2e44a59',
#                              '9abdda27-6004-4a1b-948f-c5711e5ab935',
#                              'a8215564-2612-4d26-9b6b-9deda50e41ef',
#                              '365f997b-01fe-46d8-b568-fe4fa214aff4',
#                              '5ebcc2c8-ac98-4962-b535-38d357ed10da',
#                              '5a91d965-e0b1-4efd-99f2-4e6ccf946c5d'],
#                      'Type': 'CHILD'}]},
#  {'BlockType': 'LINE',
#   'Confidence': 60.02191925048828,
#   'Geometry': {'BoundingBox': {'Height': 0.005091166123747826,
#                                'Left': 0.23086826503276825,
#                                'Top': 0.09008906781673431,
#                                'Width': 0.008670941926538944},
#                'Polygon': [{'X': 0.23086826503276825, 'Y': 0.09008906781673431},
#                            {'X': 0.23953920602798462, 'Y': 0.09008906781673431},
#                            {'X': 0.23953920602798462, 'Y': 0.09518023580312729},
#                            {'X': 0.23086826503276825,
#                             'Y': 0.09518023580312729}]},
#   'Id': '65983361-5294-49ca-b239-ee79ceffc973',
#   'Page': 1,
#   'Relationships': [{'Ids': ['ef9ab65e-8984-41d7-94bf-8e6773623be5'],
#                      'Type': 'CHILD'}],
#   'Text': 'TM'},
#  {'BlockType': 'LINE',
#   'Confidence': 87.88639068603516,
#   'Geometry': {'BoundingBox': {'Height': 0.007394592277705669,
#                                'Left': 0.1361192911863327,
#                                'Top': 0.10952621698379517,
#                                'Width': 0.02344413474202156},
#                'Polygon': [{'X': 0.1361192911863327, 'Y': 0.10952621698379517},
#                            {'X': 0.15956342220306396, 'Y': 0.10952621698379517},
#                            {'X': 0.15956342220306396, 'Y': 0.11692080646753311},
#                            {'X': 0.1361192911863327,
#                             'Y': 0.11692080646753311}]},
#   'Id': '00053d7e-aca9-4a9f-ab5e-348c756a4bd4',
#   'Page': 1,
#   'Relationships': [{'Ids': ['64e0b26d-13fb-4b18-a735-edcad93cab55'],
#                      'Type': 'CHILD'}],
#   'Text': '-'},
#  {'BlockType': 'LINE',
#   'Confidence': 95.46712493896484,
#   'Geometry': {'BoundingBox': {'Height': 0.016367552801966667,
#                                'Left': 0.1974111646413803,
#                                'Top': 0.10480916500091553,
#                                'Width': 0.02090713381767273},
#                'Polygon': [{'X': 0.1974111646413803, 'Y': 0.10480916500091553},
#                            {'X': 0.21831829845905304, 'Y': 0.10480916500091553},
#                            {'X': 0.21831829845905304, 'Y': 0.12117671966552734},
#                            {'X': 0.1974111646413803,
#                             'Y': 0.12117671966552734}]},
#   'Id': '0322fb52-d7a4-407f-aa42-9ddc181f06c3',
#   'Page': 1,
#   'Relationships': [{'Ids': ['a013806e-24bc-4d6d-8df8-c5aa80b9efa6'],
#                      'Type': 'CHILD'}],
#   'Text': '+'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.81062316894531,
#   'Geometry': {'BoundingBox': {'Height': 0.014856607653200626,
#                                'Left': 0.12001217901706696,
#                                'Top': 0.1408989429473877,
#                                'Width': 0.11609118431806564},
#                'Polygon': [{'X': 0.12001217901706696, 'Y': 0.1408989429473877},
#                            {'X': 0.2361033707857132, 'Y': 0.1408989429473877},
#                            {'X': 0.2361033707857132, 'Y': 0.15575554966926575},
#                            {'X': 0.12001217901706696,
#                             'Y': 0.15575554966926575}]},
#   'Id': '9eb96d51-4cc8-44ef-9a12-c57d0612fa08',
#   'Page': 1,
#   'Relationships': [{'Ids': ['c61ad7c1-7230-44c4-b397-c9e53eb64447'],
#                      'Type': 'CHILD'}],
#   'Text': 'ARDUINO'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.47496032714844,
#   'Geometry': {'BoundingBox': {'Height': 0.02380983531475067,
#                                'Left': 0.1181439682841301,
#                                'Top': 0.2242950201034546,
#                                'Width': 0.5950342416763306},
#                'Polygon': [{'X': 0.1181439682841301, 'Y': 0.2242950201034546},
#                            {'X': 0.7131782174110413, 'Y': 0.2242950201034546},
#                            {'X': 0.7131782174110413, 'Y': 0.24810485541820526},
#                            {'X': 0.1181439682841301,
#                             'Y': 0.24810485541820526}]},
#   'Id': '89f40669-66d7-414c-ad3b-8a1affb08765',
#   'Page': 1,
#   'Relationships': [{'Ids': ['df8f2342-372b-497b-b0fb-76cdbaf9f8e4',
#                              '9e825674-4699-4f92-8ad9-4bf7dd98c222',
#                              '2044de99-2c29-417b-a0f7-2cd7fb9e4252',
#                              '2f44db9e-f116-4eb7-b680-be3371115ed0'],
#                      'Type': 'CHILD'}],
#   'Text': 'ARDUINO MEGA 2560 REV3'},
#  {'BlockType': 'LINE',
#   'Confidence': 98.90699768066406,
#   'Geometry': {'BoundingBox': {'Height': 0.009321797639131546,
#                                'Left': 0.1173597201704979,
#                                'Top': 0.2632054090499878,
#                                'Width': 0.11097590625286102},
#                'Polygon': [{'X': 0.1173597201704979, 'Y': 0.2632054090499878},
#                            {'X': 0.22833563387393951, 'Y': 0.2632054090499878},
#                            {'X': 0.22833563387393951, 'Y': 0.27252718806266785},
#                            {'X': 0.1173597201704979,
#                             'Y': 0.27252718806266785}]},
#   'Id': '854d0434-62b1-4728-92ee-7aeca32b84bb',
#   'Page': 1,
#   'Relationships': [{'Ids': ['7b8a5bb9-00e5-4d87-882e-003269f687ec',
#                              '6605ad55-f17a-4c55-8280-594bd63b3b4b'],
#                      'Type': 'CHILD'}],
#   'Text': 'Code: A000067'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.82276916503906,
#   'Geometry': {'BoundingBox': {'Height': 0.01751326583325863,
#                                'Left': 0.1168646290898323,
#                                'Top': 0.6609065532684326,
#                                'Width': 0.7089213132858276},
#                'Polygon': [{'X': 0.1168646290898323, 'Y': 0.6609065532684326},
#                            {'X': 0.8257859945297241, 'Y': 0.6609065532684326},
#                            {'X': 0.8257859945297241, 'Y': 0.678419828414917},
#                            {'X': 0.1168646290898323, 'Y': 0.678419828414917}]},
#   'Id': '17206335-c210-4cc2-8284-026e7fa483ca',
#   'Page': 1,
#   'Relationships': [{'Ids': ['10018c7c-4091-4585-be88-5c3f31458cef',
#                              'f2725967-dc8c-4ca9-9bef-70109cf1bba2',
#                              'c231f1c8-a56d-4943-9ea3-c288f19f35db',
#                              'f7fd2148-f96a-43d3-b562-9c2d50e135c5',
#                              'fc7efd50-5744-4509-a2d7-ee40b6321635',
#                              '044d86b0-2e52-4f6c-b549-15adba79e08f',
#                              '74dc71ba-972f-4461-8673-afa45391d2e5',
#                              'f8f41a04-586f-4e49-9122-3dfc8d67544a',
#                              'eefd2816-ea43-4581-8b08-d1d51f21976a',
#                              'ee76de9c-2902-4f61-b6b4-9427cd786f7b',
#                              '201ef45c-ccc3-488e-898c-7516ff28c78c'],
#                      'Type': 'CHILD'}],
#   'Text': 'The MEGA 2560 is designed for more complex projects. With 54'},
#  {'BlockType': 'LINE',
#   'Confidence': 97.91606903076172,
#   'Geometry': {'BoundingBox': {'Height': 0.018056314438581467,
#                                'Left': 0.11779274046421051,
#                                'Top': 0.6834660768508911,
#                                'Width': 0.7451431751251221},
#                'Polygon': [{'X': 0.11779274046421051, 'Y': 0.6834660768508911},
#                            {'X': 0.8629359006881714, 'Y': 0.6834660768508911},
#                            {'X': 0.8629359006881714, 'Y': 0.7015223503112793},
#                            {'X': 0.11779274046421051,
#                             'Y': 0.7015223503112793}]},
#   'Id': '32896660-276c-4d79-9e8b-a5492bb5778e',
#   'Page': 1,
#   'Relationships': [{'Ids': ['35883a33-f0a3-4395-bb8e-74da0b8c450c',
#                              '51ebde5f-3249-4d3f-bdf3-4714bdf2f030',
#                              '6848cbec-38b8-4ba6-a960-7bac995bcd41',
#                              '5b41cf44-7e8d-4ac2-852c-07aa84c7541a',
#                              'd51ada34-597a-4412-9a0c-798948cbb4b8',
#                              '2df06759-29f8-4335-88cd-18e7cd5eda53',
#                              'c52b6a11-8685-4e52-8b8b-f85999bf9baf',
#                              '493f7e8f-123a-4065-bee4-dcc98248a7fb',
#                              '1c76feb8-d88d-43d4-a3f5-0afd43ee3779',
#                              '5bd843d2-d988-4296-b877-30fb62b3d766',
#                              'ab1eab49-40a1-4b02-a134-f1f0d12318df',
#                              '02f6bca3-5aae-41b4-bc84-62b54e705b61',
#                              'b190b63d-a75e-4f2c-80fd-f303683e9968'],
#                      'Type': 'CHILD'}],
#   'Text': 'digital I/O pins, 16 analog inputs and a larger space for your '
#           'sketch'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.86080932617188,
#   'Geometry': {'BoundingBox': {'Height': 0.017512695863842964,
#                                'Left': 0.1181742399930954,
#                                'Top': 0.7069733142852783,
#                                'Width': 0.7405485510826111},
#                'Polygon': [{'X': 0.1181742399930954, 'Y': 0.7069733142852783},
#                            {'X': 0.8587228059768677, 'Y': 0.7069733142852783},
#                            {'X': 0.8587228059768677, 'Y': 0.7244859933853149},
#                            {'X': 0.1181742399930954, 'Y': 0.7244859933853149}]},
#   'Id': '0cb6b938-9a8d-4064-9690-d6a34be4339d',
#   'Page': 1,
#   'Relationships': [{'Ids': ['778aae3c-28d1-49de-9824-fc68bbd7b4bb',
#                              'b97dd33f-8c76-40de-9cff-4debdb253a50',
#                              'd7e4a47f-7958-488a-ae4c-165cad555133',
#                              'f128b9fa-0341-42d0-bae2-1e1199524d86',
#                              '4a52bf31-36a1-41b0-9d0a-fcfee1f92990',
#                              '0909a12e-51f0-4bd5-9620-0ccdddb91ccb',
#                              '03382733-f08d-48f8-8d0e-8a35ff07a7bb',
#                              '9d017804-4a22-405e-9907-3fa059d0157b',
#                              'd731d028-6635-4165-9f37-81a98091428c',
#                              '3bb9efb7-b1e4-4e1c-b460-bcf7d4712200',
#                              '12d70700-3e37-4cb1-8e54-884c65279e40'],
#                      'Type': 'CHILD'}],
#   'Text': 'it is the recommended board for 3D printers and robotics projects.'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.70911407470703,
#   'Geometry': {'BoundingBox': {'Height': 0.0177661944180727,
#                                'Left': 0.11700459569692612,
#                                'Top': 0.7300170660018921,
#                                'Width': 0.6474965810775757},
#                'Polygon': [{'X': 0.11700459569692612, 'Y': 0.7300170660018921},
#                            {'X': 0.7645012140274048, 'Y': 0.7300170660018921},
#                            {'X': 0.7645012140274048, 'Y': 0.7477833032608032},
#                            {'X': 0.11700459569692612,
#                             'Y': 0.7477833032608032}]},
#   'Id': '168a91f7-3e07-4f26-8728-c4ec6bba45ee',
#   'Page': 1,
#   'Relationships': [{'Ids': ['22afa391-d670-418e-90ff-e9e046f3c3ff',
#                              '1fed00ab-4129-48d3-9b66-a175af9cd3d6',
#                              'f3943a7c-5c9a-4e79-99e4-bb5e4f67a86a',
#                              '2722f4d2-f917-42f5-9382-58aa35264688',
#                              'ff34bdf3-f283-4136-ad11-01f596d2966a',
#                              '22ac92e9-880e-4d80-b986-458d0d939a65',
#                              '33f24459-0937-4579-9364-470c4b1e0eef',
#                              'a63ad661-f9d7-4393-b80f-a1e5db950a0c',
#                              '4cec76a5-1669-415b-9af2-99313b7233b9'],
#                      'Type': 'CHILD'}],
#   'Text': 'This gives your projects plenty of room and opportunities.'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.72996520996094,
#   'Geometry': {'BoundingBox': {'Height': 0.014914062805473804,
#                                'Left': 0.1170692890882492,
#                                'Top': 0.7644636034965515,
#                                'Width': 0.7403159737586975},
#                'Polygon': [{'X': 0.1170692890882492, 'Y': 0.7644636034965515},
#                            {'X': 0.8573852777481079, 'Y': 0.7644636034965515},
#                            {'X': 0.8573852777481079, 'Y': 0.7793776988983154},
#                            {'X': 0.1170692890882492, 'Y': 0.7793776988983154}]},
#   'Id': 'cbe27eff-cf96-422b-9196-b8d4d61b0e36',
#   'Page': 1,
#   'Relationships': [{'Ids': ['0ae9769d-a4da-4932-843a-5022e14cf1fd',
#                              'acee7160-6e01-4499-9a10-973ececa9057',
#                              'eef36d0c-5b28-433f-a90c-0e0fd8a4754e',
#                              'c520d7a8-163b-48cd-a95b-a55d19c36e73',
#                              '4edfb3dd-68ea-4d15-9bd2-ea6b81c99b75',
#                              'a129e6df-ddb8-4b38-8b34-334e7a63b93c',
#                              'e60d83f5-f05e-4f6b-99cf-6a650120ab60',
#                              '58c10d2d-ce6c-4f23-9eb0-5c6b45f743b2',
#                              '2fc4a4ce-ae8b-4bad-8a3d-f2bec400d4e8',
#                              'aaa540b8-02b8-4235-893c-4b377c5e189b',
#                              '4bc6e2cb-2cb6-495e-b9b0-2a903b827517',
#                              '4c688074-6319-4b1b-9d1e-8e1fbeb1c807',
#                              '2fbec737-574f-424d-914d-49ec70db326d'],
#                      'Type': 'CHILD'}],
#   'Text': 'The Arduino Mega 2560 is a microcontroller board based on the '
#           'ATmega2560. It'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.35430908203125,
#   'Geometry': {'BoundingBox': {'Height': 0.015221923589706421,
#                                'Left': 0.11685657501220703,
#                                'Top': 0.7814698815345764,
#                                'Width': 0.71049964427948},
#                'Polygon': [{'X': 0.11685657501220703, 'Y': 0.7814698815345764},
#                            {'X': 0.8273561596870422, 'Y': 0.7814698815345764},
#                            {'X': 0.8273561596870422, 'Y': 0.7966918349266052},
#                            {'X': 0.11685657501220703,
#                             'Y': 0.7966918349266052}]},
#   'Id': '2729e90e-45ca-410f-8bb7-7e6adfce2fb0',
#   'Page': 1,
#   'Relationships': [{'Ids': ['d7ea604f-bba1-4472-90ac-ecfc0225c666',
#                              'ca087dc4-b70b-49e8-b75f-e094bb5fd356',
#                              'dcc3b757-aedf-4b30-8eb8-441ccb5f20eb',
#                              '90efe822-b058-45ba-b2a1-16618532659d',
#                              '1d76205d-98b4-4070-a570-f35844e6eadb',
#                              '0d45d99f-a3ef-4fa0-a61c-c9642078ae07',
#                              'b4c11881-8a9a-44ff-b98c-b342bcebb459',
#                              '2973884e-c301-466c-a7ec-c9fb35f86290',
#                              '9b32c1b1-0dff-4836-a5df-cf09ae57f250',
#                              '9dff6b81-b821-4a63-ab54-373a84f3fb48',
#                              'cabdfc3c-c4f2-4ef6-a5f6-54cfa7955d6e',
#                              'd5de0d7a-fb06-43a5-b3ff-8fdf507548a3',
#                              'dd7d9b91-b274-4091-a7d6-d50016c8881d',
#                              'ee426a9f-cd56-4b90-b695-f1865dcabb73',
#                              '55b42318-142e-4a3d-b942-d45ca5ceb22c'],
#                      'Type': 'CHILD'}],
#   'Text': 'has 54 digital input/output pins (of which 15 can be used as PWM '
#           'outputs), 16'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.49598693847656,
#   'Geometry': {'BoundingBox': {'Height': 0.015356282703578472,
#                                'Left': 0.11777004599571228,
#                                'Top': 0.7985774874687195,
#                                'Width': 0.7552982568740845},
#                'Polygon': [{'X': 0.11777004599571228, 'Y': 0.7985774874687195},
#                            {'X': 0.8730683326721191, 'Y': 0.7985774874687195},
#                            {'X': 0.8730683326721191, 'Y': 0.8139337301254272},
#                            {'X': 0.11777004599571228,
#                             'Y': 0.8139337301254272}]},
#   'Id': 'aab76d80-8661-482e-af4b-cda4c2e44a59',
#   'Page': 1,
#   'Relationships': [{'Ids': ['2aa8abf6-f0f6-4a45-b926-b3f634cb4253',
#                              'bf0a458b-99d1-49e4-9df2-07aa3e308061',
#                              'ba27b86f-08f4-4538-9021-00000f150949',
#                              '5a8c5ffa-3e19-4c7e-974b-43ca11b37ac2',
#                              'd099d7bf-6382-497f-a7e7-d4de5636a241',
#                              '7706808f-be19-4f46-aae6-1cadef81b23c',
#                              'c77fb53a-5c0a-4614-9419-588747a5cd78',
#                              '5636dd30-b1e2-48ea-8b75-43c83686854b',
#                              'ebc66a47-c707-47eb-a602-85ea6fcf7cf5',
#                              '6411448d-d624-4bf7-8485-5411bcdbefba',
#                              '3775cb4f-38f5-4a83-9d1a-909db40a35de',
#                              'e699a87c-64d0-4f64-991e-e31b29214c84',
#                              'da4395da-cabb-4231-84d3-4ca957fd6584',
#                              '03fddaeb-75e5-4726-bab4-82020ba1e0fc'],
#                      'Type': 'CHILD'}],
#   'Text': 'analog inputs, 4 UARTs (hardware serial ports), a 16 MHz crystal '
#           'oscillator, a USB'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.79306030273438,
#   'Geometry': {'BoundingBox': {'Height': 0.01486995443701744,
#                                'Left': 0.11746444553136826,
#                                'Top': 0.8165414333343506,
#                                'Width': 0.7578909397125244},
#                'Polygon': [{'X': 0.11746444553136826, 'Y': 0.8165414333343506},
#                            {'X': 0.8753554224967957, 'Y': 0.8165414333343506},
#                            {'X': 0.8753554224967957, 'Y': 0.8314113616943359},
#                            {'X': 0.11746444553136826,
#                             'Y': 0.8314113616943359}]},
#   'Id': '9abdda27-6004-4a1b-948f-c5711e5ab935',
#   'Page': 1,
#   'Relationships': [{'Ids': ['33a400e0-fa32-40cb-b0da-bd60fc94d5cb',
#                              'b15b854c-5401-4832-9a3e-0765ec186e86',
#                              'd43ddfb4-004c-4a27-a436-a30921b3e89f',
#                              '406db243-320d-4fa6-9633-3fac0c18f50c',
#                              'bde2d44f-f452-4c3e-b677-2589441844c6',
#                              'd2fa0905-5d56-41a7-b39d-f13ced83705a',
#                              '1eab8e09-4262-4adb-a83a-cb28e6286dfd',
#                              '528befb4-0488-4750-b3ce-cafb0086fa6d',
#                              '20d400db-5239-4fbf-bd86-d92fc5ad82ec',
#                              'e6311a5e-580a-4011-94bc-a506d8e91361',
#                              'c2b2b0f5-112d-4819-b462-f981513fe04f',
#                              '95afe44a-604a-4fb9-bef7-ee0e50507270',
#                              'e0f5481d-a06d-446e-aa1d-e5b1f0cb344e',
#                              'f8aa05ec-b5c3-46a4-a3d4-cca01a99de30'],
#                      'Type': 'CHILD'}],
#   'Text': 'connection, a power jack, an ICSP header, and a reset button. It '
#           'contains everything'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.8606948852539,
#   'Geometry': {'BoundingBox': {'Height': 0.015274657867848873,
#                                'Left': 0.11742132157087326,
#                                'Top': 0.8337315320968628,
#                                'Width': 0.7465671300888062},
#                'Polygon': [{'X': 0.11742132157087326, 'Y': 0.8337315320968628},
#                            {'X': 0.86398845911026, 'Y': 0.8337315320968628},
#                            {'X': 0.86398845911026, 'Y': 0.849006175994873},
#                            {'X': 0.11742132157087326, 'Y': 0.849006175994873}]},
#   'Id': 'a8215564-2612-4d26-9b6b-9deda50e41ef',
#   'Page': 1,
#   'Relationships': [{'Ids': ['1682b9d5-9654-49b3-b079-40234bdee281',
#                              '496346b3-fe5b-4692-a944-8043a5a2de55',
#                              '8583c46b-aa9e-4f84-927e-eb5398e2a7fe',
#                              '73f4c31a-32ce-4d09-b365-eb08ab9c4b8f',
#                              'ed79103b-7cd8-4b78-8e72-fd743a29f691',
#                              '66d921c5-dea2-46c5-aa48-c064c9a47ef1',
#                              '4ede37d0-7bde-466a-a22a-dc468c34c975',
#                              '74fcb841-f929-4560-94e1-6301bdb5e4bb',
#                              'bfba6e79-c869-4302-8eba-62bba1c39e73',
#                              '85d3663c-941b-4bea-ba4a-2c828d80aed7',
#                              'bc8279ff-ab65-4348-85fa-8555620ccb49',
#                              '46adb1fe-0297-4cd7-8ff2-efe08e0083e3',
#                              '2775eac2-7f2b-4029-8261-526586c87604',
#                              'f7702383-ef1f-4936-94c6-2695fae7c418'],
#                      'Type': 'CHILD'}],
#   'Text': 'needed to support the microcontroller; simply connect it to a '
#           'computer with a USB'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.86026763916016,
#   'Geometry': {'BoundingBox': {'Height': 0.014881998300552368,
#                                'Left': 0.11721339821815491,
#                                'Top': 0.8515058755874634,
#                                'Width': 0.7559182047843933},
#                'Polygon': [{'X': 0.11721339821815491, 'Y': 0.8515058755874634},
#                            {'X': 0.8731316328048706, 'Y': 0.8515058755874634},
#                            {'X': 0.8731316328048706, 'Y': 0.8663878440856934},
#                            {'X': 0.11721339821815491,
#                             'Y': 0.8663878440856934}]},
#   'Id': '365f997b-01fe-46d8-b568-fe4fa214aff4',
#   'Page': 1,
#   'Relationships': [{'Ids': ['d5ecff92-0d2a-4b09-aa11-b59ef153335c',
#                              'f114bb9e-0770-4820-ab07-39f60236a03f',
#                              '8d738ff7-ed03-4867-a624-8d7cb81544e7',
#                              'e1060d3c-68a1-4111-8020-9f02d6827e3e',
#                              'b50da2ae-85e9-4b65-a0a5-7a3de87a8edb',
#                              '69baee9a-b35a-4e32-bc4e-ae659c9ae716',
#                              'fe279c11-ffc4-4c4c-b7c8-ec11552f58b6',
#                              '909f6757-f4f5-4ab9-8183-0fc2c5180821',
#                              'bde08c5c-1d96-4eeb-aa85-db2e68ed50e4',
#                              '46c55779-7a2a-43a9-896b-f42f87ae9723',
#                              'a964c9aa-fffe-4504-afe6-4d02d17232a7',
#                              'ec449ae9-d1f1-4c60-b4c5-b80fb6e1a7ef',
#                              '141123f7-83ab-45df-96bf-15c6c2513e18',
#                              'ff3c7ba1-fc1b-4775-854e-b80a82a8cadf',
#                              '2bbaf8a9-e0cb-4a58-ac14-de17ed9b57bb',
#                              'cb4a8e1d-453b-4fc9-b07b-71b4516b221e'],
#                      'Type': 'CHILD'}],
#   'Text': 'cable or power it with a AC-to-DC adapter or battery to get '
#           'started. The Mega 2560'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.92677307128906,
#   'Geometry': {'BoundingBox': {'Height': 0.014736002311110497,
#                                'Left': 0.11758637428283691,
#                                'Top': 0.8690669536590576,
#                                'Width': 0.7409403920173645},
#                'Polygon': [{'X': 0.11758637428283691, 'Y': 0.8690669536590576},
#                            {'X': 0.8585267663002014, 'Y': 0.8690669536590576},
#                            {'X': 0.8585267663002014, 'Y': 0.8838029503822327},
#                            {'X': 0.11758637428283691,
#                             'Y': 0.8838029503822327}]},
#   'Id': '5ebcc2c8-ac98-4962-b535-38d357ed10da',
#   'Page': 1,
#   'Relationships': [{'Ids': ['61e11d22-3602-4437-95cc-23c235e99db2',
#                              'cb2ddbdc-6b37-4d03-bd56-1751ddeb3995',
#                              '93348035-d5e7-4218-bd77-4cbf0f2fcf7c',
#                              'f5dfda7f-d912-40e9-bf07-afb163bf8e25',
#                              '64f2b64e-e055-45b0-8339-5fcb94fae8d2',
#                              'f5b033a2-3234-4d87-b1f1-267e520debd4',
#                              'cff84d98-d8cc-45dd-bcd7-afcbd0c9a153',
#                              '580a7a77-23d1-4d36-ae25-4888a2abfbe5',
#                              '23e76a40-be8b-4e8a-969f-214dd8f91094',
#                              'a332cbd9-c2a8-4a20-a81c-b777711cc90b',
#                              '31640afa-a730-4115-bd56-b978f2aabb7f',
#                              '0b41fc40-5603-4d5a-8e84-598d5892a9f3',
#                              '1896b04d-9595-4c6b-a0fa-626bd035ada4',
#                              '97589984-2286-463e-b0be-e1daa56efc76'],
#                      'Type': 'CHILD'}],
#   'Text': 'board is compatible with most shields designed for the Uno and the '
#           'former boards'},
#  {'BlockType': 'LINE',
#   'Confidence': 98.74707794189453,
#   'Geometry': {'BoundingBox': {'Height': 0.011616699397563934,
#                                'Left': 0.11728591471910477,
#                                'Top': 0.8863240480422974,
#                                'Width': 0.24291366338729858},
#                'Polygon': [{'X': 0.11728591471910477, 'Y': 0.8863240480422974},
#                            {'X': 0.36019957065582275, 'Y': 0.8863240480422974},
#                            {'X': 0.36019957065582275, 'Y': 0.8979407548904419},
#                            {'X': 0.11728591471910477,
#                             'Y': 0.8979407548904419}]},
#   'Id': '5a91d965-e0b1-4efd-99f2-4e6ccf946c5d',
#   'Page': 1,
#   'Relationships': [{'Ids': ['21b59538-6cfe-4d95-b541-1cf40a7ee788',
#                              '25c8ec05-1559-4607-81f7-31361d9c0f4f',
#                              '98a8ce4f-9e1a-4dd8-8f7c-b76008bd0a5f'],
#                      'Type': 'CHILD'}],
#   'Text': 'Duemilanove or Diecimila.'},
#  {'BlockType': 'WORD',
#   'Confidence': 60.02191925048828,
#   'Geometry': {'BoundingBox': {'Height': 0.005091166123747826,
#                                'Left': 0.23086826503276825,
#                                'Top': 0.09008906781673431,
#                                'Width': 0.008670941926538944},
#                'Polygon': [{'X': 0.23086826503276825, 'Y': 0.09008906781673431},
#                            {'X': 0.23953920602798462, 'Y': 0.09008906781673431},
#                            {'X': 0.23953920602798462, 'Y': 0.09518023580312729},
#                            {'X': 0.23086826503276825,
#                             'Y': 0.09518023580312729}]},
#   'Id': 'ef9ab65e-8984-41d7-94bf-8e6773623be5',
#   'Page': 1,
#   'Text': 'TM',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 87.88639068603516,
#   'Geometry': {'BoundingBox': {'Height': 0.007394592277705669,
#                                'Left': 0.1361192911863327,
#                                'Top': 0.10952621698379517,
#                                'Width': 0.02344413474202156},
#                'Polygon': [{'X': 0.1361192911863327, 'Y': 0.10952621698379517},
#                            {'X': 0.15956342220306396, 'Y': 0.10952621698379517},
#                            {'X': 0.15956342220306396, 'Y': 0.11692080646753311},
#                            {'X': 0.1361192911863327,
#                             'Y': 0.11692080646753311}]},
#   'Id': '64e0b26d-13fb-4b18-a735-edcad93cab55',
#   'Page': 1,
#   'Text': '-',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 95.46712493896484,
#   'Geometry': {'BoundingBox': {'Height': 0.016367552801966667,
#                                'Left': 0.1974111646413803,
#                                'Top': 0.10480916500091553,
#                                'Width': 0.02090713381767273},
#                'Polygon': [{'X': 0.1974111646413803, 'Y': 0.10480916500091553},
#                            {'X': 0.21831829845905304, 'Y': 0.10480916500091553},
#                            {'X': 0.21831829845905304, 'Y': 0.12117671966552734},
#                            {'X': 0.1974111646413803,
#                             'Y': 0.12117671966552734}]},
#   'Id': 'a013806e-24bc-4d6d-8df8-c5aa80b9efa6',
#   'Page': 1,
#   'Text': '+',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.81062316894531,
#   'Geometry': {'BoundingBox': {'Height': 0.014856607653200626,
#                                'Left': 0.12001217901706696,
#                                'Top': 0.1408989429473877,
#                                'Width': 0.11609118431806564},
#                'Polygon': [{'X': 0.12001217901706696, 'Y': 0.1408989429473877},
#                            {'X': 0.2361033707857132, 'Y': 0.1408989429473877},
#                            {'X': 0.2361033707857132, 'Y': 0.15575554966926575},
#                            {'X': 0.12001217901706696,
#                             'Y': 0.15575554966926575}]},
#   'Id': 'c61ad7c1-7230-44c4-b397-c9e53eb64447',
#   'Page': 1,
#   'Text': 'ARDUINO',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.1165542602539,
#   'Geometry': {'BoundingBox': {'Height': 0.02355804480612278,
#                                'Left': 0.1181439682841301,
#                                'Top': 0.22454681992530823,
#                                'Width': 0.2057153582572937},
#                'Polygon': [{'X': 0.1181439682841301, 'Y': 0.22454681992530823},
#                            {'X': 0.3238593339920044, 'Y': 0.22454681992530823},
#                            {'X': 0.3238593339920044, 'Y': 0.24810485541820526},
#                            {'X': 0.1181439682841301,
#                             'Y': 0.24810485541820526}]},
#   'Id': 'df8f2342-372b-497b-b0fb-76cdbaf9f8e4',
#   'Page': 1,
#   'Text': 'ARDUINO',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.66219329833984,
#   'Geometry': {'BoundingBox': {'Height': 0.023167012259364128,
#                                'Left': 0.34342458844184875,
#                                'Top': 0.2245243489742279,
#                                'Width': 0.12602126598358154},
#                'Polygon': [{'X': 0.34342458844184875, 'Y': 0.2245243489742279},
#                            {'X': 0.4694458842277527, 'Y': 0.2245243489742279},
#                            {'X': 0.4694458842277527, 'Y': 0.24769136309623718},
#                            {'X': 0.34342458844184875,
#                             'Y': 0.24769136309623718}]},
#   'Id': '9e825674-4699-4f92-8ad9-4bf7dd98c222',
#   'Page': 1,
#   'Text': 'MEGA',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.65203094482422,
#   'Geometry': {'BoundingBox': {'Height': 0.023513955995440483,
#                                'Left': 0.4884469211101532,
#                                'Top': 0.22431649267673492,
#                                'Width': 0.10191386193037033},
#                'Polygon': [{'X': 0.4884469211101532, 'Y': 0.22431649267673492},
#                            {'X': 0.5903607606887817, 'Y': 0.22431649267673492},
#                            {'X': 0.5903607606887817, 'Y': 0.24783045053482056},
#                            {'X': 0.4884469211101532,
#                             'Y': 0.24783045053482056}]},
#   'Id': '2044de99-2c29-417b-a0f7-2cd7fb9e4252',
#   'Page': 1,
#   'Text': '2560',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.46906280517578,
#   'Geometry': {'BoundingBox': {'Height': 0.023710835725069046,
#                                'Left': 0.613162636756897,
#                                'Top': 0.2242950201034546,
#                                'Width': 0.1000155583024025},
#                'Polygon': [{'X': 0.613162636756897, 'Y': 0.2242950201034546},
#                            {'X': 0.7131782174110413, 'Y': 0.2242950201034546},
#                            {'X': 0.7131782174110413, 'Y': 0.24800585210323334},
#                            {'X': 0.613162636756897, 'Y': 0.24800585210323334}]},
#   'Id': '2f44db9e-f116-4eb7-b680-be3371115ed0',
#   'Page': 1,
#   'Text': 'REV3',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 98.53236389160156,
#   'Geometry': {'BoundingBox': {'Height': 0.009289001114666462,
#                                'Left': 0.1173597201704979,
#                                'Top': 0.2632054090499878,
#                                'Width': 0.0415041446685791},
#                'Polygon': [{'X': 0.1173597201704979, 'Y': 0.2632054090499878},
#                            {'X': 0.1588638573884964, 'Y': 0.2632054090499878},
#                            {'X': 0.1588638573884964, 'Y': 0.2724944055080414},
#                            {'X': 0.1173597201704979, 'Y': 0.2724944055080414}]},
#   'Id': '7b8a5bb9-00e5-4d87-882e-003269f687ec',
#   'Page': 1,
#   'Text': 'Code:',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.2816390991211,
#   'Geometry': {'BoundingBox': {'Height': 0.009136169217526913,
#                                'Left': 0.16446098685264587,
#                                'Top': 0.26339101791381836,
#                                'Width': 0.06387464702129364},
#                'Polygon': [{'X': 0.16446098685264587, 'Y': 0.26339101791381836},
#                            {'X': 0.22833563387393951, 'Y': 0.26339101791381836},
#                            {'X': 0.22833563387393951, 'Y': 0.27252718806266785},
#                            {'X': 0.16446098685264587,
#                             'Y': 0.27252718806266785}]},
#   'Id': '6605ad55-f17a-4c55-8280-594bd63b3b4b',
#   'Page': 1,
#   'Text': 'A000067',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.98690795898438,
#   'Geometry': {'BoundingBox': {'Height': 0.014097575098276138,
#                                'Left': 0.1168646290898323,
#                                'Top': 0.6611177921295166,
#                                'Width': 0.03966416418552399},
#                'Polygon': [{'X': 0.1168646290898323, 'Y': 0.6611177921295166},
#                            {'X': 0.1565287858247757, 'Y': 0.6611177921295166},
#                            {'X': 0.1565287858247757, 'Y': 0.6752153635025024},
#                            {'X': 0.1168646290898323, 'Y': 0.6752153635025024}]},
#   'Id': '10018c7c-4091-4585-be88-5c3f31458cef',
#   'Page': 1,
#   'Text': 'The',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.75019836425781,
#   'Geometry': {'BoundingBox': {'Height': 0.013746174983680248,
#                                'Left': 0.16580098867416382,
#                                'Top': 0.6615052223205566,
#                                'Width': 0.06648091226816177},
#                'Polygon': [{'X': 0.16580098867416382, 'Y': 0.6615052223205566},
#                            {'X': 0.232281893491745, 'Y': 0.6615052223205566},
#                            {'X': 0.232281893491745, 'Y': 0.6752513647079468},
#                            {'X': 0.16580098867416382,
#                             'Y': 0.6752513647079468}]},
#   'Id': 'f2725967-dc8c-4ca9-9bef-70109cf1bba2',
#   'Page': 1,
#   'Text': 'MEGA',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.88333892822266,
#   'Geometry': {'BoundingBox': {'Height': 0.014308187179267406,
#                                'Left': 0.23916180431842804,
#                                'Top': 0.6612169742584229,
#                                'Width': 0.05416319891810417},
#                'Polygon': [{'X': 0.23916180431842804, 'Y': 0.6612169742584229},
#                            {'X': 0.2933250069618225, 'Y': 0.6612169742584229},
#                            {'X': 0.2933250069618225, 'Y': 0.6755251288414001},
#                            {'X': 0.23916180431842804,
#                             'Y': 0.6755251288414001}]},
#   'Id': 'c231f1c8-a56d-4943-9ea3-c288f19f35db',
#   'Page': 1,
#   'Text': '2560',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.97722625732422,
#   'Geometry': {'BoundingBox': {'Height': 0.013890828005969524,
#                                'Left': 0.30113568902015686,
#                                'Top': 0.6614576578140259,
#                                'Width': 0.015477336011826992},
#                'Polygon': [{'X': 0.30113568902015686, 'Y': 0.6614576578140259},
#                            {'X': 0.31661301851272583, 'Y': 0.6614576578140259},
#                            {'X': 0.31661301851272583, 'Y': 0.6753485202789307},
#                            {'X': 0.30113568902015686,
#                             'Y': 0.6753485202789307}]},
#   'Id': 'f7fd2148-f96a-43d3-b562-9c2d50e135c5',
#   'Page': 1,
#   'Text': 'is',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.96957397460938,
#   'Geometry': {'BoundingBox': {'Height': 0.016810791566967964,
#                                'Left': 0.324597030878067,
#                                'Top': 0.6610965728759766,
#                                'Width': 0.09731731563806534},
#                'Polygon': [{'X': 0.324597030878067, 'Y': 0.6610965728759766},
#                            {'X': 0.42191433906555176, 'Y': 0.6610965728759766},
#                            {'X': 0.42191433906555176, 'Y': 0.6779073476791382},
#                            {'X': 0.324597030878067, 'Y': 0.6779073476791382}]},
#   'Id': 'fc7efd50-5744-4509-a2d7-ee40b6321635',
#   'Page': 1,
#   'Text': 'designed',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.98548126220703,
#   'Geometry': {'BoundingBox': {'Height': 0.014285563491284847,
#                                'Left': 0.43051838874816895,
#                                'Top': 0.6609065532684326,
#                                'Width': 0.032454799860715866},
#                'Polygon': [{'X': 0.43051838874816895, 'Y': 0.6609065532684326},
#                            {'X': 0.4629732072353363, 'Y': 0.6609065532684326},
#                            {'X': 0.4629732072353363, 'Y': 0.67519211769104},
#                            {'X': 0.43051838874816895, 'Y': 0.67519211769104}]},
#   'Id': '044d86b0-2e52-4f6c-b549-15adba79e08f',
#   'Page': 1,
#   'Text': 'for',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.98440551757812,
#   'Geometry': {'BoundingBox': {'Height': 0.01053149439394474,
#                                'Left': 0.4715881049633026,
#                                'Top': 0.6646165251731873,
#                                'Width': 0.05568802356719971},
#                'Polygon': [{'X': 0.4715881049633026, 'Y': 0.6646165251731873},
#                            {'X': 0.5272761583328247, 'Y': 0.6646165251731873},
#                            {'X': 0.5272761583328247, 'Y': 0.6751480102539062},
#                            {'X': 0.4715881049633026, 'Y': 0.6751480102539062}]},
#   'Id': '74dc71ba-972f-4461-8673-afa45391d2e5',
#   'Page': 1,
#   'Text': 'more',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.92162322998047,
#   'Geometry': {'BoundingBox': {'Height': 0.017375202849507332,
#                                'Left': 0.5359960198402405,
#                                'Top': 0.6610445976257324,
#                                'Width': 0.091271311044693},
#                'Polygon': [{'X': 0.5359960198402405, 'Y': 0.6610445976257324},
#                            {'X': 0.6272673606872559, 'Y': 0.6610445976257324},
#                            {'X': 0.6272673606872559, 'Y': 0.678419828414917},
#                            {'X': 0.5359960198402405, 'Y': 0.678419828414917}]},
#   'Id': 'f8f41a04-586f-4e49-9122-3dfc8d67544a',
#   'Page': 1,
#   'Text': 'complex',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 98.7732162475586,
#   'Geometry': {'BoundingBox': {'Height': 0.016580646857619286,
#                                'Left': 0.6359534859657288,
#                                'Top': 0.6617791652679443,
#                                'Width': 0.09498924016952515},
#                'Polygon': [{'X': 0.6359534859657288, 'Y': 0.6617791652679443},
#                            {'X': 0.7309427261352539, 'Y': 0.6617791652679443},
#                            {'X': 0.7309427261352539, 'Y': 0.6783598065376282},
#                            {'X': 0.6359534859657288, 'Y': 0.6783598065376282}]},
#   'Id': 'eefd2816-ea43-4581-8b08-d1d51f21976a',
#   'Page': 1,
#   'Text': 'projects.',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.87118530273438,
#   'Geometry': {'BoundingBox': {'Height': 0.014016439206898212,
#                                'Left': 0.7386060953140259,
#                                'Top': 0.6611064076423645,
#                                'Width': 0.05249534174799919},
#                'Polygon': [{'X': 0.7386060953140259, 'Y': 0.6611064076423645},
#                            {'X': 0.7911013960838318, 'Y': 0.6611064076423645},
#                            {'X': 0.7911013960838318, 'Y': 0.675122857093811},
#                            {'X': 0.7386060953140259, 'Y': 0.675122857093811}]},
#   'Id': 'ee76de9c-2902-4f61-b6b4-9427cd786f7b',
#   'Page': 1,
#   'Text': 'With',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.94733428955078,
#   'Geometry': {'BoundingBox': {'Height': 0.013769246637821198,
#                                'Left': 0.7999007701873779,
#                                'Top': 0.6611382365226746,
#                                'Width': 0.025885172188282013},
#                'Polygon': [{'X': 0.7999007701873779, 'Y': 0.6611382365226746},
#                            {'X': 0.8257859945297241, 'Y': 0.6611382365226746},
#                            {'X': 0.8257859945297241, 'Y': 0.6749074459075928},
#                            {'X': 0.7999007701873779, 'Y': 0.6749074459075928}]},
#   'Id': '201ef45c-ccc3-488e-898c-7516ff28c78c',
#   'Page': 1,
#   'Text': '54',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.86650085449219,
#   'Geometry': {'BoundingBox': {'Height': 0.017768066376447678,
#                                'Left': 0.11779274046421051,
#                                'Top': 0.6837543249130249,
#                                'Width': 0.06746463477611542},
#                'Polygon': [{'X': 0.11779274046421051, 'Y': 0.6837543249130249},
#                            {'X': 0.18525737524032593, 'Y': 0.6837543249130249},
#                            {'X': 0.18525737524032593, 'Y': 0.7015223503112793},
#                            {'X': 0.11779274046421051,
#                             'Y': 0.7015223503112793}]},
#   'Id': '35883a33-f0a3-4395-bb8e-74da0b8c450c',
#   'Page': 1,
#   'Text': 'digital',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 75.60450744628906,
#   'Geometry': {'BoundingBox': {'Height': 0.017304524779319763,
#                                'Left': 0.1944858729839325,
#                                'Top': 0.6834660768508911,
#                                'Width': 0.03325291723012924},
#                'Polygon': [{'X': 0.1944858729839325, 'Y': 0.6834660768508911},
#                            {'X': 0.22773878276348114, 'Y': 0.6834660768508911},
#                            {'X': 0.22773878276348114, 'Y': 0.7007706165313721},
#                            {'X': 0.1944858729839325, 'Y': 0.7007706165313721}]},
#   'Id': '51ebde5f-3249-4d3f-bdf3-4714bdf2f030',
#   'Page': 1,
#   'Text': 'I/O',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 98.84172821044922,
#   'Geometry': {'BoundingBox': {'Height': 0.016516927629709244,
#                                'Left': 0.23718175292015076,
#                                'Top': 0.6847778558731079,
#                                'Width': 0.050316981971263885},
#                'Polygon': [{'X': 0.23718175292015076, 'Y': 0.6847778558731079},
#                            {'X': 0.28749874234199524, 'Y': 0.6847778558731079},
#                            {'X': 0.28749874234199524, 'Y': 0.7012947797775269},
#                            {'X': 0.23718175292015076,
#                             'Y': 0.7012947797775269}]},
#   'Id': '6848cbec-38b8-4ba6-a960-7bac995bcd41',
#   'Page': 1,
#   'Text': 'pins,',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.88179779052734,
#   'Geometry': {'BoundingBox': {'Height': 0.013800700195133686,
#                                'Left': 0.2973727881908417,
#                                'Top': 0.6847002506256104,
#                                'Width': 0.024839254096150398},
#                'Polygon': [{'X': 0.2973727881908417, 'Y': 0.6847002506256104},
#                            {'X': 0.3222120404243469, 'Y': 0.6847002506256104},
#                            {'X': 0.3222120404243469, 'Y': 0.6985009908676147},
#                            {'X': 0.2973727881908417, 'Y': 0.6985009908676147}]},
#   'Id': '5b41cf44-7e8d-4ac2-852c-07aa84c7541a',
#   'Page': 1,
#   'Text': '16',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.67445373535156,
#   'Geometry': {'BoundingBox': {'Height': 0.01702946051955223,
#                                'Left': 0.33115094900131226,
#                                'Top': 0.6842140555381775,
#                                'Width': 0.0720638781785965},
#                'Polygon': [{'X': 0.33115094900131226, 'Y': 0.6842140555381775},
#                            {'X': 0.40321484208106995, 'Y': 0.6842140555381775},
#                            {'X': 0.40321484208106995, 'Y': 0.7012434601783752},
#                            {'X': 0.33115094900131226,
#                             'Y': 0.7012434601783752}]},
#   'Id': 'd51ada34-597a-4412-9a0c-798948cbb4b8',
#   'Page': 1,
#   'Text': 'analog',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.81378173828125,
#   'Geometry': {'BoundingBox': {'Height': 0.016700033098459244,
#                                'Left': 0.4117923974990845,
#                                'Top': 0.684568464756012,
#                                'Width': 0.06674918532371521},
#                'Polygon': [{'X': 0.4117923974990845, 'Y': 0.684568464756012},
#                            {'X': 0.4785415828227997, 'Y': 0.684568464756012},
#                            {'X': 0.4785415828227997, 'Y': 0.7012684941291809},
#                            {'X': 0.4117923974990845, 'Y': 0.7012684941291809}]},
#   'Id': '2df06759-29f8-4335-88cd-18e7cd5eda53',
#   'Page': 1,
#   'Text': 'inputs',
#   'TextType': 'PRINTED'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.97029113769531,
#   'Geometry': {'BoundingBox': {'Height': 0.014397216960787773,
#                                'Left': 0.48751208186149597,
#                                'Top': 0.6839854121208191,
#                                'Width': 0.03847489878535271},
#                'Polygon': [{'X': 0.48751208186149597, 'Y': 0.6839854121208191},
#                            {'X': 0.5259869694709778, 'Y': 0.6839854121208191},
#                            {'X': 0.5259869694709778, 'Y': 0.6983826756477356},
#                            {'X': 0.48751208186149597,
#                             'Y': 0.6983826756477356}]},
#   'Id': 'c52b6a11-8685-4e52-8b8b-f85999bf9baf',
#   'Page': 1,
#   'Text': 'and',
# ...
# Type: LINE
# Text: which operate with 5V and with the board that uses ATSAM3X8E, that operate with 3.3V.
# Confidence: 99.28%
#
#
# Block Id: 2387e109-8a0b-4ccd-a9a7-18ed0b4feb99
# Type: LINE
# Text: The second one is a not connected pin, that is reserved for future purposes.
# Confidence: 99.77%
#
#
# Block Id: 87a88df1-9edb-49f6-aef2-462853c3f735
# Type: LINE
# Text: Stronger RESET circuit.
# Confidence: 98.12%
#
#
# Block Id: f7e45a47-efca-4492-a8f7-bb0dca21282e
# Type: LINE
# Text: Atmega 16U2 replace the 8U2.
# Confidence: 97.60%
#
#
# Block Id: 9ebd3ddc-8680-403d-b24a-a7f4bf11dfb5
# Type: LINE
# Text: 00000000 00000000000
# Confidence: 86.42%
#
#
# Block Id: a15caf21-1847-4935-9a70-2afe8db8ed27
# Type: LINE
# Text: 000
# Confidence: 92.26%
#
#
# Block Id: 51bd9459-9732-4a23-ba76-93d8fda4d695
# Type: LINE
# Text: MEGA
# Confidence: 94.98%
#
#
# Block Id: 78af5377-cf17-4692-9d1c-039b4fc224ae
# Type: LINE
# Text: 000
# Confidence: 78.99%
#
#
# Block Id: 8857db76-debf-47f4-a127-b121f3b82bf0
# Type: LINE
# Text: 00
# Confidence: 55.76%
#
#
# Block Id: d97d7c0c-5fa0-476e-ba1a-b22f9ba96fb2
# Type: LINE
# Text: +10/01
# Confidence: 16.82%
#
#
# Block Id: 26fee757-baa6-4b92-a5cb-62e460ec0261
# Type: LINE
# Text: ARDUING
# Confidence: 51.88%
#
#
# Block Id: 814b3fbb-9015-4abb-8b3f-98396863caf4
# Type: LINE
# Text: 2800
# Confidence: 21.40%
#
#
# Block Id: d3aa678e-4f93-44aa-9143-e81c90a3c7f6
# Type: LINE
# Text: ARDUTHO
# Confidence: 27.98%
#
#
# Block Id: db6fc9d3-133c-4988-bdd6-4b4de208c6f1
# Type: LINE
# Text: co
# Confidence: 20.75%
#
#
# Block Id: 6543fe85-0466-4e44-b555-c278e5703ff4
# Type: LINE
# Text: ELECTRONICE
# Confidence: 61.18%
#
#
# Block Id: 1c6499ef-9d28-4347-ae03-45905bfd09ba
# Type: LINE
# Text: 120
# Confidence: 26.77%
#
#
# Block Id: 356dbb01-8a43-46ab-ad94-ad57f17ef53e
# Type: LINE
# Text: PLATTORN
# Confidence: 60.85%
#
#
# Block Id: e1f13b73-a10e-4a5e-b979-575a5bb10095
# Type: LINE
# Text: 00
# Confidence: 66.84%
#
#
# Block Id: f560d218-940c-45ab-80f1-765cd3446b95
# Type: LINE
# Text: e e
# Confidence: 69.41%
#
#
# Block Id: 5897af73-d818-4b2d-b71f-101949ca2818
# Type: LINE
# Text: MEGA
# Confidence: 91.62%
#
#
# Block Id: 1b82a86f-e2bd-4519-b5df-1a188c983b1f
# Type: LINE
# Text: 2560
# Confidence: 95.18%
#
#
# Block Id: 7989e087-47c9-4a92-9357-cfaf7a0117eb
# Type: LINE
# Text: 654
# Confidence: 18.02%
#
#
# Block Id: 4db9d82e-70f9-4e15-b8ed-eaf6ed907224
# Type: LINE
# Text: ARDUINO
# Confidence: 97.19%
#
#
# Block Id: 9bc87730-aa29-4f75-8465-3e96740762e7
# Type: LINE
# Text: POWER
# Confidence: 94.38%
#
#
# Block Id: c2ee5e7c-9b1a-42f2-aae2-d135710a4009
# Type: LINE
# Text: COMPLIANE
# Confidence: 20.37%
#
#
# Block Id: 55a94d8e-cd6a-42e2-ac04-c5ee948e1783
# Type: LINE
# Text: 00000000 00000000
# Confidence: 93.41%
#
#
# Block Id: 6bc5341b-dee5-4199-8296-01c67c7b33da
# Type: LINE
# Text: a
# Confidence: 28.71%
#
#
# Block Id: 37f4b737-2f6c-4fb2-8049-0c7b7031c66a
# Type: LINE
# Text: ARDUINO CC
# Confidence: 90.65%
#
#
# Block Id: f1b65657-7daa-469b-9b4c-7654bf588e3f
# Type: LINE
# Text: o -
# Confidence: 77.34%
#
#
# Block Id: 2f52f94f-defb-4233-8bda-903242946d54
# Type: LINE
# Text: https://store.arduino.cc/usa/arduino-mega-2560-rev311-30-17
# Confidence: 73.95%
#
#
# Block Id: 79130680-4168-433f-b30f-c7c1898f75fb
# Type: WORD
# Text: 1.0
# Confidence: 99.85%
#
#
# Block Id: 4b891d43-6951-4a93-b958-9154fd0083b6
# Type: WORD
# Text: pinout:
# Confidence: 92.71%
#
#
# Block Id: c1b69a66-b2a8-481f-ab18-de11b7030f27
# Type: WORD
# Text: SDA
# Confidence: 99.71%
#
#
# Block Id: 98b5f6e9-8ee2-4e67-b544-ca015515acc3
# Type: WORD
# Text: and
# Confidence: 99.81%
#
#
# Block Id: 21b96993-d431-47f5-afd7-5ad72b108edc
# Type: WORD
# Text: SCL
# Confidence: 99.32%
#
#
# Block Id: 31a1bd1b-b418-4985-8de4-b96468fa7729
# Type: WORD
# Text: pins
# Confidence: 98.38%
#
#
# Block Id: 9b2444fc-ec67-43ec-89f9-9341e70f1ee2
# Type: WORD
# Text: -
# Confidence: 95.91%
#
#
# Block Id: 0df5a68c-b495-4345-b67c-7230222e1e57
# Type: WORD
# Text: near
# Confidence: 99.55%
#
#
# Block Id: b4835355-39a8-43ba-8f36-c2d6ca528c34
# Type: WORD
# Text: to
# Confidence: 99.95%
#
#
# Block Id: 5d39205e-333e-4df1-9db2-d485d5e3975f
# Type: WORD
# Text: the
# Confidence: 99.98%
#
#
# Block Id: dc48935d-ba48-4315-be68-6f9987041afb
# Type: WORD
# Text: AREF
# Confidence: 99.17%
#
#
# Block Id: b54197f8-4047-496f-bc30-639c8a711e0b
# Type: WORD
# Text: pin
# Confidence: 99.53%
#
#
# Block Id: 072842b1-9c81-4614-ba87-c09384443f92
# Type: WORD
# Text: -
# Confidence: 95.22%
#
#
# Block Id: b4c21f93-0ee6-4cde-9368-3ab45216623e
# Type: WORD
# Text: and
# Confidence: 99.65%
#
#
# Block Id: b9321d38-148d-4ab4-99cc-f9871666eb55
# Type: WORD
# Text: two
# Confidence: 99.91%
#
#
# Block Id: 75f16c2e-b637-451c-88be-50944875b0e9
# Type: WORD
# Text: other
# Confidence: 99.97%
#
#
# Block Id: c0ec39e0-4388-4425-89d7-3fa9192a2459
# Type: WORD
# Text: new
# Confidence: 99.81%
#
#
# Block Id: 6eb14209-dd0d-419e-b624-fb8f178b5c50
# Type: WORD
# Text: pins
# Confidence: 97.75%
#
#
# Block Id: 74aa682e-dd8d-4ffc-8541-257bd258077e
# Type: WORD
# Text: placed
# Confidence: 99.94%
#
#
# Block Id: d21951e4-8b02-4a07-a352-fa8fca70647a
# Type: WORD
# Text: near
# Confidence: 99.71%
#
#
# Block Id: 56a431e9-3ba4-4d3a-a033-7cb3ce5484dc
# Type: WORD
# Text: to
# Confidence: 99.98%
#
#
# Block Id: 39bc4dd0-66da-43b5-a612-23b22220e8e3
# Type: WORD
# Text: the
# Confidence: 99.99%
#
#
# Block Id: b5d05008-7ba9-488e-b1d3-597fb81ddb0e
# Type: WORD
# Text: RESET
# Confidence: 99.54%
#
#
# Block Id: 31a4886b-c9e8-421c-8377-e9b1ba908c34
# Type: WORD
# Text: pin,
# Confidence: 98.76%
#
#
# Block Id: dd46f5ea-dac3-4b92-a32b-8574900f58f3
# Type: WORD
# Text: the
# Confidence: 99.98%
#
#
# Block Id: 3debbe53-d1a4-4436-91bc-c6f4491cd8e7
# Type: WORD
# Text: IOREF
# Confidence: 94.29%
#
#
# Block Id: e2f588c7-8344-4ea8-b69c-db34b4535001
# Type: WORD
# Text: that
# Confidence: 99.98%
#
#
# Block Id: b3773b34-cb36-4b48-9da3-b107c02841fc
# Type: WORD
# Text: allow
# Confidence: 99.96%
#
#
# Block Id: 743b4821-9f69-499d-a107-7101daef1d1f
# Type: WORD
# Text: the
# Confidence: 99.99%
#
#
# Block Id: 9638dbaf-c16a-4e13-84e4-93e48ffb11e0
# Type: WORD
# Text: shields
# Confidence: 99.85%
#
#
# Block Id: 0eb50c77-5ee4-43e7-85a4-a1b1766d335b
# Type: WORD
# Text: to
# Confidence: 99.97%
#
#
# Block Id: dab1b552-23ba-43a2-a00c-c771fa80a657
# Type: WORD
# Text: adapt
# Confidence: 99.71%
#
#
# Block Id: 14150466-efa2-47f6-a181-7670ced377f9
# Type: WORD
# Text: to
# Confidence: 99.97%
#
#
# Block Id: 00b78351-08bd-4b4f-af50-97afd42015a1
# Type: WORD
# Text: the
# Confidence: 99.99%
#
#
# Block Id: 69b1dd85-f07b-46b6-9773-172044549b58
# Type: WORD
# Text: voltage
# Confidence: 99.83%
#
#
# Block Id: e3e4facb-340c-4f98-949f-5e86e042b35e
# Type: WORD
# Text: provided
# Confidence: 99.96%
#
#
# Block Id: 99605d61-368d-4904-94e0-41ab8b8160c4
# Type: WORD
# Text: from
# Confidence: 99.98%
#
#
# Block Id: 110ca604-37d2-4b66-bcda-ff1ffd61c894
# Type: WORD
# Text: the
# Confidence: 99.99%
#
#
# Block Id: 818cc29f-b761-4f68-a479-f37f99eeed54
# Type: WORD
# Text: board.
# Confidence: 99.02%
#
#
# Block Id: 15f6ddac-daeb-4a94-af44-e651ddcbe191
# Type: WORD
# Text: In
# Confidence: 97.50%
#
#
# Block Id: d5b5da0c-a913-4c84-8d42-b7aab47e943b
# Type: WORD
# Text: future,
# Confidence: 96.84%
#
#
# Block Id: 2a02dd36-560f-4282-ab62-5b3c96bd62cc
# Type: WORD
# Text: shields
# Confidence: 99.59%
#
#
# Block Id: e802b471-3df1-4ad8-a689-00aa39763be0
# Type: WORD
# Text: will
# Confidence: 99.95%
#
#
# Block Id: e894b0dc-43e0-4382-8535-a473e3b5dbe8
# Type: WORD
# Text: be
# Confidence: 99.95%
#
#
# Block Id: 52462a20-b63f-48d9-af96-ff63b0b75dd4
# Type: WORD
# Text: compatible
# Confidence: 99.81%
#
#
# Block Id: abd47bd0-ff44-4d0a-abbb-67d229e0d941
# Type: WORD
# Text: both
# Confidence: 99.99%
#
#
# Block Id: 3ed1db48-2e26-42d2-8685-481363f44db3
# Type: WORD
# Text: with
# Confidence: 99.99%
#
#
# Block Id: 5ffff5f7-ea92-4f9c-b317-f8fad93e3d2d
# Type: WORD
# Text: the
# Confidence: 99.99%
#
#
# Block Id: 6afb9667-af9b-4773-ac5b-b07557e73270
# Type: WORD
# Text: board
# Confidence: 99.92%
#
#
# Block Id: 886bef21-1db4-492c-9125-7722427bad69
# Type: WORD
# Text: that
# Confidence: 99.98%
#
#
# Block Id: 1c59f170-2194-4eb3-ab3a-1271f8a357d9
# Type: WORD
# Text: use
# Confidence: 99.91%
#
#
# Block Id: 18d50cfb-5e3a-431e-9d06-9c60fad5411a
# Type: WORD
# Text: the
# Confidence: 99.97%
#
#
# Block Id: a19cab26-8038-4cc1-bbe6-df382565e292
# Type: WORD
# Text: AVR,
# Confidence: 99.06%
#
#
# Block Id: bbce0104-8198-4fc4-8dcf-2d65e87d7e5b
# Type: WORD
# Text: which
# Confidence: 99.99%
#
#
# Block Id: 885b37c2-97f6-4b60-bfb2-7d59d91e95af
# Type: WORD
# Text: operate
# Confidence: 99.93%
#
#
# Block Id: c76e87ef-02e1-4fe5-b062-6b0063cba499
# Type: WORD
# Text: with
# Confidence: 99.99%
#
#
# Block Id: f8f53a35-700a-45fa-b599-d4f1557d06c8
# Type: WORD
# Text: 5V
# Confidence: 97.84%
#
#
# Block Id: ab70a502-a341-48cb-9d6d-c9e83534c0ba
# Type: WORD
# Text: and
# Confidence: 99.89%
#
#
# Block Id: 2d230b2d-91fa-4836-90ff-2bd979316b03
# Type: WORD
# Text: with
# Confidence: 99.99%
#
#
# Block Id: 11932457-73ae-4ccf-8cc6-390b627efec5
# Type: WORD
# Text: the
# Confidence: 99.99%
#
#
# Block Id: cb7691cd-9c6e-4ef4-a55c-15f654ff408f
# Type: WORD
# Text: board
# Confidence: 99.93%
#
#
# Block Id: 629f630f-9296-40b1-92e3-ba3c3026820c
# Type: WORD
# Text: that
# Confidence: 99.98%
#
#
# Block Id: 728b341c-8a4c-414f-ad5c-26f0aebbe4f4
# Type: WORD
# Text: uses
# Confidence: 99.89%
#
#
# Block Id: 7c3b4621-5558-4dcc-aa00-903c853a2392
# Type: WORD
# Text: ATSAM3X8E,
# Confidence: 93.74%
#
#
# Block Id: 4d7a118d-011d-4c6f-a0a4-40d166693e33
# Type: WORD
# Text: that
# Confidence: 99.98%
#
#
# Block Id: 5f4e3b76-2610-4026-9b84-85b0eeb57fb7
# Type: WORD
# Text: operate
# Confidence: 99.93%
#
#
# Block Id: 3ef2e7ee-065c-4482-a610-002b8994961e
# Type: WORD
# Text: with
# Confidence: 99.99%
#
#
# Block Id: 5f824f6f-076f-40ee-94c1-63857fe17177
# Type: WORD
# Text: 3.3V.
# Confidence: 98.17%
#
#
# Block Id: 120f360d-2dbd-4412-a98f-997bec4739ed
# Type: WORD
# Text: The
# Confidence: 99.98%
#
#
# Block Id: 21d5e617-2632-47b2-bae9-88594397485c
# Type: WORD
# Text: second
# Confidence: 99.90%
#
#
# Block Id: a35eff8e-6954-4a95-bc50-dc9a327ba8dd
# Type: WORD
# Text: one
# Confidence: 99.97%
#
#
# Block Id: 7ecdbc60-0ad0-4e73-8d01-79cfdf31a907
# Type: WORD
# Text: is
# Confidence: 99.97%
#
#
# Block Id: 8b8b8c93-5abc-45da-998b-45a6f17feed1
# Type: WORD
# Text: a
# Confidence: 99.92%
#
#
# Block Id: b0583704-32ba-4d03-ba74-3592d2448757
# Type: WORD
# Text: not
# Confidence: 99.96%
#
#
# Block Id: ee5a28e3-76bb-4d24-bdbe-aef613958388
# Type: WORD
# Text: connected
# Confidence: 99.97%
#
#
# Block Id: 8908491f-53cb-4089-b03f-a9bcd115f79e
# Type: WORD
# Text: pin,
# Confidence: 98.58%
#
#
# Block Id: 77844d5a-a19b-4d74-9007-eb579ff46c39
# Type: WORD
# Text: that
# Confidence: 99.99%
#
#
# Block Id: fb237955-dff1-4c41-921f-03b6d0a43753
# Type: WORD
# Text: is
# Confidence: 99.97%
#
#
# Block Id: 2e4bcb12-19f9-4f05-a77c-faffced3ba5e
# Type: WORD
# Text: reserved
# Confidence: 99.93%
#
#
# Block Id: e3544c19-7a77-4b8c-bcad-dd64ae00698b
# Type: WORD
# Text: for
# Confidence: 99.98%
#
#
# Block Id: b997603d-2b56-4cfc-87b7-768158a76e3d
# Type: WORD
# Text: future
# Confidence: 99.90%
#
#
# Block Id: ef1a380e-7e03-4b0b-a2f2-d3001cc7c0fe
# Type: WORD
# Text: purposes.
# Confidence: 98.79%
#
#
# Block Id: cea713b3-2c3d-4eae-afd1-c0fcd51547fa
# Type: WORD
# Text: Stronger
# Confidence: 98.72%
#
#
# Block Id: aafdda97-ab93-4cd6-8cf8-f1bc455863bd
# Type: WORD
# Text: RESET
# Confidence: 99.47%
#
#
# Block Id: ec99db8d-e92b-4660-9912-41dfeb45ec3a
# Type: WORD
# Text: circuit.
# Confidence: 96.16%
#
#
# Block Id: 8f4f3855-0a23-43c3-9a5d-c831b6c819a9
# Type: WORD
# Text: Atmega
# Confidence: 99.27%
#
#
# Block Id: 5b3636fe-156b-4124-8475-dad508c6d8a1
# Type: WORD
# Text: 16U2
# Confidence: 93.10%
#
#
# Block Id: e705a436-0314-4926-b7cd-ffb528e32be2
# Type: WORD
# Text: replace
# Confidence: 99.78%
#
#
# Block Id: 265c039c-658f-4169-a79a-b4d1521c750e
# Type: WORD
# Text: the
# Confidence: 99.99%
#
#
# Block Id: 414bacd2-368f-4411-95b4-ca77238dc844
# Type: WORD
# Text: 8U2.
# Confidence: 95.84%
#
#
# Block Id: 64cf4696-c38f-456d-b983-4b4aab076edb
# Type: WORD
# Text: 00000000
# Confidence: 96.48%
#
#
# Block Id: d672d822-9617-4cd0-aac0-0d0b600e3c78
# Type: WORD
# Text: 00000000000
# Confidence: 76.35%
#
#
# Block Id: bd62a6df-2032-404c-9fcf-40654c782091
# Type: WORD
# Text: 000
# Confidence: 92.26%
#
#
# Block Id: 736617c3-2b7d-432b-811d-d7b6bc071bca
# Type: WORD
# Text: MEGA
# Confidence: 94.98%
#
#
# Block Id: 7c3b3c5e-c1d8-45ed-9cff-2f9bdf9b813a
# Type: WORD
# Text: 000
# Confidence: 78.99%
#
#
# Block Id: 9cd8a01d-e89d-4d38-a89f-3bdc5f16a832
# Type: WORD
# Text: 00
# Confidence: 55.76%
#
#
# Block Id: c5ecb9eb-b2e7-4dd7-b93a-3eac0c0a809d
# Type: WORD
# Text: +10/01
# Confidence: 16.82%
#
#
# Block Id: 47f53ccd-e0df-4167-9586-b050541384bd
# Type: WORD
# Text: ARDUING
# Confidence: 51.88%
#
#
# Block Id: a3d4bf82-3f57-4394-9fb6-67c7f2cbc3df
# Type: WORD
# Text: 2800
# Confidence: 21.40%
#
#
# Block Id: 9ec4362e-a53b-4e00-98e7-f9985d1c4a04
# Type: WORD
# Text: ARDUTHO
# Confidence: 27.98%
#
#
# Block Id: a81559f4-f1c9-44be-a537-98232850eaae
# Type: WORD
# Text: co
# Confidence: 20.75%
#
#
# Block Id: 492fa6ef-4210-45e1-88cf-b66dd621faa5
# Type: WORD
# Text: ELECTRONICE
# Confidence: 61.18%
#
#
# Block Id: d9ad5e7b-aa8b-487a-9ce8-9e8367a807de
# Type: WORD
# Text: 120
# Confidence: 26.77%
#
#
# Block Id: 8b20d5a1-8190-4d07-9f89-a1ce9f98ff13
# Type: WORD
# Text: PLATTORN
# Confidence: 60.85%
#
#
# Block Id: f9d517b5-77b5-4ae8-8abe-2ad5b82859fb
# Type: WORD
# Text: 00
# Confidence: 66.84%
#
#
# Block Id: cda20d7c-d454-4a13-93fd-e720e3e391b2
# Type: WORD
# Text: e
# Confidence: 46.31%
#
#
# Block Id: 08d34d47-2a9e-467e-8e35-c5ac6f1489a2
# Type: WORD
# Text: e
# Confidence: 92.52%
#
#
# Block Id: efd0c385-1e03-40cc-b0ff-743fef6a0f07
# Type: WORD
# Text: MEGA
# Confidence: 91.62%
#
#
# Block Id: d3d86c5f-28a4-412a-b6f3-874c5b4b960a
# Type: WORD
# Text: 2560
# Confidence: 95.18%
#
#
# Block Id: e58c95cb-ec62-4717-aab4-c74c8a41c449
# Type: WORD
# Text: 654
# Confidence: 18.02%
#
#
# Block Id: 5eae1b4e-2d37-4abb-8f31-ceaeede282b4
# Type: WORD
# Text: ARDUINO
# Confidence: 97.19%
#
#
# Block Id: f191de54-8438-4750-b4b2-2cb5029518fe
# Type: WORD
# Text: POWER
# Confidence: 94.38%
#
#
# Block Id: 641baa7e-87c6-49c6-8a5e-66e2fcb1d568
# Type: WORD
# Text: COMPLIANE
# Confidence: 20.37%
#
#
# Block Id: a23be79d-74a6-4249-93f0-f128e02b1bba
# Type: WORD
# Text: 00000000
# Confidence: 91.28%
#
#
# Block Id: f11820c5-b73d-45e6-a7fd-ccef6d2bd055
# Type: WORD
# Text: 00000000
# Confidence: 95.54%
#
#
# Block Id: 0f2bb794-f674-443e-becb-e29c18c9e688
# Type: WORD
# Text: a
# Confidence: 28.71%
#
#
# Block Id: f0af2c6d-c92d-49ff-b421-0e1c86dd6e15
# Type: WORD
# Text: ARDUINO
# Confidence: 97.54%
#
#
# Block Id: 8c38e8b4-b8f6-4bb5-9e30-3621eecfd7ea
# Type: WORD
# Text: CC
# Confidence: 83.76%
#
#
# Block Id: bd100aa3-c4e7-4d42-8638-de66e268bbc1
# Type: WORD
# Text: o
# Confidence: 69.92%
#
#
# Block Id: baaaf81b-3b04-4b56-9d49-8eab98376326
# Type: WORD
# Text: -
# Confidence: 84.76%
#
#
# Block Id: 81a84ef2-e8ee-478e-9533-999bba52d6b4
# Type: WORD
# Text: https://store.arduino.cc/usa/arduino-mega-2560-rev311-30-17
# Confidence: 73.95%
#
#
# Block Id: 774e1115-6773-424a-b904-bdab4e90815b
# Type: TABLE
# Confidence: 92.51%
#
#
# Block Id: 8015bf33-bed8-43a4-92b4-69479cb2871c
# Type: CELL
# Confidence: 44.96%
#
#
# Block Id: 66efbbe1-944b-4161-97ef-a5c6f7eb5599
# Type: CELL
# Confidence: 31.68%
#
#
# Block Id: 9072d0ad-7acd-4989-8db5-d6b4a2771dc7
# Type: CELL
# Confidence: 69.63%
#
#
# Block Id: 9c7af10a-be36-4a11-a134-9585150ed316
# Type: CELL
# Confidence: 49.07%
#
#
# Block Id: 0c040c10-4454-4d6a-aa8e-067dcde1248d
# Type: CELL
# Confidence: 80.16%
#
#
# Block Id: 2265f6c5-848e-4e2f-a8bd-9cbe5687d7e9
# Type: CELL
# Confidence: 56.49%
#
#
# Block Id: f408edfa-24fa-40a7-9e4b-1ea610793732
# Type: CELL
# Confidence: 80.45%
#
#
# Block Id: ff907149-e24a-4d67-8cc7-1629f61693e6
# Type: CELL
# Confidence: 56.69%
#
#
# Block Id: 658face1-8840-4dbd-a2b8-4e33451f529b
# Type: CELL
# Confidence: 80.66%
#
#
# Block Id: 01a2436c-9284-4c9b-88d5-0b9b8af6295d
# Type: CELL
# Confidence: 56.84%
#
#
# Block Id: 70162217-4dc9-4c34-b41f-c95dc32c25d8
# Type: CELL
# Confidence: 74.27%
#
#
# Block Id: 7b9c1c82-abec-4a06-8a50-b6ee02aecdd4
# Type: CELL
# Confidence: 52.34%
#
#
# Block Id: 36312aad-5aa4-4fcb-8683-efe766c29964
# Type: CELL
# Confidence: 44.08%
#
#
# Block Id: c95940db-38fb-483e-94f2-b45c6092780a
# Type: CELL
# Confidence: 31.06%
#
#
# Block Id: af9f2ed0-ffed-4fd7-a295-bebb6f6ad8b5
# Type: CELL
# Confidence: 35.69%
#
#
# Block Id: b4a73847-1f1c-43e5-9c24-1a991fc8fe1c
# Type: CELL
# Confidence: 25.15%
#
#
# Block Id: 7c9cefb3-5477-43d6-b40c-7b2f46c37ba3
# Type: CELL
# Confidence: 42.43%
#
#
# Block Id: 4058d1b5-a7a7-484b-bd83-2a2289741120
# Type: CELL
# Confidence: 29.90%
#
#
# Block Id: 59f7b6eb-3734-4c00-aabc-2bfa06d4c610
# Type: CELL
# Confidence: 44.83%
#
#
# Block Id: 9753c8fe-78a7-4eef-841f-fcb0249c256c
# Type: CELL
# Confidence: 31.59%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [90], in <cell line: 151>()
#     147     return csv
#     149 response_blocks = GetResults(jobId, file_name)
# --> 151 generate_table_csv(table_result, blocks_map, table_index)
#
# NameError: name 'table_result' is not defined
